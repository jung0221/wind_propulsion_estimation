# %%
import xarray as xr
import pandas as pd
import numpy as np
import os
import folium
from tqdm import tqdm
import concurrent
import time
import threading

# %%
      
print("[INFO] Reading dataset")
ds = xr.open_dataset('../gribs/antartida.grib', engine="cfgrib")
ds
# Out:
# [INFO] Reading dataset
# <xarray.Dataset>
# Dimensions:     (time: 8784, latitude: 5, longitude: 9)
# Coordinates:
#     number      int32 ...
#   * time        (time) datetime64[ns] 2020-01-01 ... 2020-12-31T23:00:00
#     step        timedelta64[ns] ...
#     surface     float64 ...
#   * latitude    (latitude) float64 23.0 22.75 22.5 22.25 22.0
#   * longitude   (longitude) float64 -49.0 -48.75 -48.5 ... -47.5 -47.25 -47.0
#     valid_time  (time) datetime64[ns] ...
# Data variables:
#     u10         (time, latitude, longitude) float32 ...
#     v10         (time, latitude, longitude) float32 ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
lon = 22.5
lat = -48
u10_point1 = self.ds.u10.sel(latitude=lat, longitude=lon, method="nearest")
v10_point1 = self.ds.v10.sel(latitude=lat, longitude=lon, method="nearest")

current_time = pd.Timestamp("2020-04-05 04:00:00")
