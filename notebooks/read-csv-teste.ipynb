# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv(r'..\..\dados\castro_alves_afra\forces_CFD.csv')
df['Angulo']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#      ...
# 67    330
# 68    330
# 69    330
# 70    330
# 71    330
# Name: Angulo, Length: 72, dtype: int64
